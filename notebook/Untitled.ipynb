# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gas = pd.read_csv('..\data\GAS.csv')

# %%
gas.head()
# Out:
#        Date  \
# 0  1/1/1983
# 1  2/1/1983
# 2  3/1/1983
# 3  4/1/1983
# 4  5/1/1983
#
#   Connecticut Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)  \
# 0                                         $2,687.50
# 1                                         $2,735.10
# 2                                         $3,120.30
# 3                                         $3,187.20
# 4                                         $3,239.50
#
#   Maine Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)  \
# 0                                         $1,209.00
# 1                                         $1,284.50
# 2                                         $1,439.00
# 3                                         $1,335.70
# 4                                         $1,494.40
#
#   Massachusetts Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)  \
# 0                                         $5,406.30
# ...

# %%
east = [
    'Connecticut Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)',
    'Maine Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)',
    'Massachusetts Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)',
    'New Hampshire Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)',
    'Rhode Island Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)',
    'Vermont Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)',
    'Maryland Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)',
    'New Jersey Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)',
    'New York Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)',
    'Pennsylvania Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)'
]
east = gas[['Date'] + east]

# %%
east.tail(15)
# Out:
#            Date  \
# 456   1/15/2021
# 457   2/15/2021
# 458   3/15/2021
# 459   4/15/2021
# 460   5/15/2021
# 461   6/15/2021
# 462   7/15/2021
# 463   8/15/2021
# 464   9/15/2021
# 465  10/15/2021
# 466  11/15/2021
# 467  12/15/2021
# 468   1/15/2022
# 469   2/15/2022
# 470   3/15/2022
#
#     Connecticut Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)  \
# 456                                         $3,411.70
# 457                                         $3,369.00
# 458                                         $3,722.00
# 459                                         $3,735.00
# 460                                         $3,929.30
# 461                                         $3,920.20
# 462                                         $3,851.00
# 463                                         $3,865.50
# 464                                         $3,795.30
# 465                                         $3,877.30
# ...

# %%
year =  ['1/15/2019', '2/15/2019', '3/15/2019', '4/15/2019', '5/15/2019', '6/15/2019', '7/15/2019', '8/15/2019', '9/15/2019', '10/15/2019', '11/15/2019', '12/15/2019'] 
eastt = east[east['Date'].isin(year)]

# %%
eastt.head(10)
# Out:
#            Date  \
# 432   1/15/2019
# 433   2/15/2019
# 434   3/15/2019
# 435   4/15/2019
# 436   5/15/2019
# 437   6/15/2019
# 438   7/15/2019
# 439   8/15/2019
# 440   9/15/2019
# 441  10/15/2019
#
#     Connecticut Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)  \
# 432                                         $3,585.80
# 433                                         $3,578.90
# 434                                         $3,598.10
# 435                                         $3,688.50
# 436                                         $3,820.30
# 437                                         $3,829.90
# 438                                         $3,837.30
# 439                                         $3,793.00
# 440                                         $3,653.70
# 441                                         $3,686.60
#
#     Maine Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)  \
# ...

# %%
east.sort_values()
# Out:
# <bound method DataFrame.sort_values of            Date  \
# 0      1/1/1983
# 1      2/1/1983
# 2      3/1/1983
# 3      4/1/1983
# 4      5/1/1983
# ..          ...
# 466  11/15/2021
# 467  12/15/2021
# 468   1/15/2022
# 469   2/15/2022
# 470   3/15/2022
#
#     Connecticut Total Gasoline All Sales/Deliveries by Prime Supplier (Thousand Gallons per Day)  \
# 0                                           $2,687.50
# 1                                           $2,735.10
# 2                                           $3,120.30
# 3                                           $3,187.20
# 4                                           $3,239.50
# ..                                                 ...
# 466                                         $3,787.10
# 467                                         $3,633.50
# 468                                         $3,613.60
# 469                                         $3,571.10
# 470                                         $3,497.00
#
# ...
