# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sqlalchemy import create_engine, text

# %%
apple = pd.read_csv("data/apple.csv")
lly = pd.read_csv("data/lly.csv")
bac = pd.read_csv("data/bac.csv")
cop = pd.read_csv("data/cop.csv")
cvx = pd.read_csv("data/cvx.csv")
exxon = pd.read_csv("data/exxon.csv")
gld = pd.read_csv("data/gld.csv")
hca = pd.read_csv("data/hca.csv")
jnj = pd.read_csv("data/jnj.csv")
jpm = pd.read_csv("data/jpm.csv")
ma = pd.read_csv("data/ma.csv")
meta = pd.read_csv("data/meta.csv")
msft = pd.read_csv("data/msft.csv")
nvda = pd.read_csv("data/nvda.csv")
pfe = pd.read_csv("data/pfe.csv")
qqq = pd.read_csv("data/qqq.csv")
shell = pd.read_csv("data/shell.csv")
slv = pd.read_csv("data/slv.csv")
spy = pd.read_csv("data/spy.csv")
tsla = pd.read_csv("data/tslaa.csv")
unh = pd.read_csv("data/unh.csv")
uvxy = pd.read_csv("data/uvxy.csv")
v = pd.read_csv("data/v.csv")
wfc = pd.read_csv("data/wfc.csv")
google = pd.read_csv("data/google.csv")
cpi = pd.read_excel("data/cpi.xls")
gas = pd.read_excel("data/gass.xls")
house = pd.read_excel("data/houses price.xls")
mortgage = pd.read_excel("data/mortgage index.xls")

# %%
techh = [apple,msft,meta,google,nvda]
engeryy = [exxon,shell,cvx,cop]
healthcaree = [lly,unh,jnj,pfe]
bankk = [jpm,v,ma,wfc,bac]
otherr = [tsla,spy,qqq,uvxy,gld,slv]

# %%
tech= pd.concat(techh, ignore_index=True)
engery = pd.concat(engeryy, ignore_index=True)
healthcare = pd.concat(healthcaree, ignore_index=True)
bank = pd.concat(bankk, ignore_index=True)
other = pd.concat(otherr, ignore_index=True)

# %%
cpi.tail(43)
# Out:
#               Unnamed: 0 Unnamed: 1
# 130  2020-01-01 00:00:00   2.491633
# 131  2020-02-01 00:00:00   2.340293
# 132  2020-03-01 00:00:00    1.53078
# 133  2020-04-01 00:00:00   0.285958
# 134  2020-05-01 00:00:00   0.051281
# 135  2020-06-01 00:00:00   0.581271
# 136  2020-07-01 00:00:00   0.933336
# 137  2020-08-01 00:00:00   1.264507
# 138  2020-09-01 00:00:00   1.332004
# 139  2020-10-01 00:00:00   1.130982
# 140  2020-11-01 00:00:00   1.122155
# 141  2020-12-01 00:00:00   1.323012
# 142  2021-01-01 00:00:00   1.365915
# 143  2021-02-01 00:00:00   1.630144
# 144  2021-03-01 00:00:00   2.554887
# 145  2021-04-01 00:00:00   4.091169
# 146  2021-05-01 00:00:00   4.926312
# 147  2021-06-01 00:00:00   5.308077
# 148  2021-07-01 00:00:00   5.263089
# 149  2021-08-01 00:00:00   5.173857
# 150  2021-09-01 00:00:00   5.331813
# 151  2021-10-01 00:00:00   6.168981
# 152  2021-11-01 00:00:00   6.756291
# 153  2021-12-01 00:00:00   6.985817
# 154  2022-01-01 00:00:00   7.431089
# ...

# %%
dates = cpi['Unnamed: 0'].tail(43)
values = cpi['Unnamed: 1'].tail(43)
plt.figure(figsize=(10, 6))  
plt.plot(dates, values, marker='o', linestyle='-')
plt.title('CPI Data ')
plt.xlabel('Date')
plt.ylabel('CPI Value')
plt.xticks(rotation=45)
# Out:
# (array([18262., 18444., 18628., 18809., 18993., 19174., 19358., 19539.]),
#  [Text(18262.0, 0, '2020-01'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19174.0, 0, '2022-07'),
#   Text(19358.0, 0, '2023-01'),
#   Text(19539.0, 0, '2023-07')])

# %%
house.tail(14)
# Out:
#               Unnamed: 0 Unnamed: 1
# 238  2020-01-01 00:00:00     329000
# 239  2020-04-01 00:00:00     322600
# 240  2020-07-01 00:00:00     337500
# 241  2020-10-01 00:00:00     358700
# 242  2021-01-01 00:00:00     369800
# 243  2021-04-01 00:00:00     382600
# 244  2021-07-01 00:00:00     411200
# 245  2021-10-01 00:00:00     423600
# 246  2022-01-01 00:00:00     433100
# 247  2022-04-01 00:00:00     449300
# 248  2022-07-01 00:00:00     468000
# 249  2022-10-01 00:00:00     479500
# 250  2023-01-01 00:00:00     429000
# 251  2023-04-01 00:00:00     416100

# %%
dates = house['Unnamed: 0'].tail(14)
values = house['Unnamed: 1'].tail(14)
plt.figure(figsize=(10, 6))  
plt.plot(dates, values, marker='o', linestyle='-')
plt.title('House Prices ')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
# Out:
# (array([18262., 18383., 18506., 18628., 18748., 18871., 18993., 19113.,
#         19236., 19358., 19478.]),
#  [Text(18262.0, 0, '2020-01'),
#   Text(18383.0, 0, '2020-05'),
#   Text(18506.0, 0, '2020-09'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18748.0, 0, '2021-05'),
#   Text(18871.0, 0, '2021-09'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19113.0, 0, '2022-05'),
#   Text(19236.0, 0, '2022-09'),
#   Text(19358.0, 0, '2023-01'),
#   Text(19478.0, 0, '2023-05')])

# %%
gas.tail(45)
# Out:
#     Unnamed: 0  Unnamed: 1
# 323 2020-01-15       2.636
# 324 2020-02-15       2.533
# 325 2020-03-15       2.329
# 326 2020-04-15       1.938
# 327 2020-05-15       1.961
# 328 2020-06-15       2.170
# 329 2020-07-15       2.272
# 330 2020-08-15       2.272
# 331 2020-09-15       2.274
# 332 2020-10-15       2.248
# 333 2020-11-15       2.200
# 334 2020-12-15       2.284
# 335 2021-01-15       2.420
# 336 2021-02-15       2.587
# 337 2021-03-15       2.898
# 338 2021-04-15       2.948
# 339 2021-05-15       3.076
# 340 2021-06-15       3.157
# 341 2021-07-15       3.231
# 342 2021-08-15       3.255
# 343 2021-09-15       3.272
# 344 2021-10-15       3.384
# 345 2021-11-15       3.491
# 346 2021-12-15       3.406
# 347 2022-01-15       3.413
# 348 2022-02-15       3.611
# 349 2022-03-15       4.322
# 350 2022-04-15       4.213
# 351 2022-05-15       4.545
# 352 2022-06-15       5.032
# 353 2022-07-15       4.668
# 354 2022-08-15       4.087
# 355 2022-09-15       3.817
# ...

# %%
dates = gas['Unnamed: 0'].tail(45)
values = gas['Unnamed: 1'].tail(45)
plt.figure(figsize=(10, 6))  
plt.plot(dates, values, marker='o', linestyle='-')
plt.title('Gas Prices ')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
# Out:
# (array([18262., 18444., 18628., 18809., 18993., 19174., 19358., 19539.]),
#  [Text(18262.0, 0, '2020-01'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19174.0, 0, '2022-07'),
#   Text(19358.0, 0, '2023-01'),
#   Text(19539.0, 0, '2023-07')])

# %%
tsla
# Out:
#             Date Close/Last     Volume      Open      High        Low
# 0     10/13/2023    $251.12  102296800   $258.90   $259.60    $250.22
# 1     10/12/2023    $258.87  111508100   $262.92   $265.41  $256.6307
# 2     10/11/2023    $262.99  103706300   $266.20   $268.60    $260.90
# 3     10/10/2023    $263.62  122656000   $257.75   $268.94    $257.65
# 4     10/09/2023    $259.67  101377900   $255.31   $261.36    $252.05
# ...          ...        ...        ...       ...       ...        ...
# 1253  10/19/2018   $17.3333  140171390   $17.826  $17.9773     $16.90
# 1254  10/18/2018    $17.594   81028024  $17.9527  $18.0667   $17.5333
# 1255  10/17/2018   $18.1187  129554170  $18.8267  $18.8467   $17.7202
# 1256  10/16/2018   $18.4393  142516729  $17.7133  $18.4917   $17.4827
# 1257  10/15/2018    $17.306   92835344  $17.2707   $17.552   $16.9691
#
# [1258 rows x 6 columns]

# %%
database_name = 'Stock analysis' 
connection_string = "postgresql://postgres:postgres@localhost:5433/{Stock analysis}"

# %%
engine = create_engine ("postgresql://postgres:postgres@localhost:5433/Stock analysis")

# %%
query = '''
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '2020-01-02'
UNION
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '2020-05-01'
UNION
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '2020-09-01'
UNION
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '01/04/2021'
UNION
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '05/03/2021'
UNION
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '9/1/2021'
UNION
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '1/3/2022'
UNION
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '5/2/2022'
UNION
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '9/1/2022'
UNION
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '1/3/2023'
UNION
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '5/1/2023'
UNION
SELECT t_date, t_close_last
FROM tsla_stock
WHERE t_date = '9/1/2023'
;
'''

with engine.connect() as connection:
 result = connection.execute(text(query))
with engine.connect() as connection:
     sc1 = pd.read_sql(text(query), con = connection)
sc1.head(50)
# Out:
#         t_date t_close_last
# 0   2022-01-03    $399.9266
# 1   2022-05-02      $300.98
# 2   2021-09-01    $244.6966
# 3   2022-09-01      $277.16
# 4   2021-01-04    $243.2566
# 5   2023-05-01      $161.83
# 6   2020-09-01      $158.35
# 7   2021-05-03      $228.30
# 8   2020-01-02      $28.684
# 9   2020-05-01     $46.7547
# 10  2023-09-01      $245.01
# 11  2023-01-03      $108.10

# %%
sc11 = sc1.sort_values(by='t_date')

# %%
sc11
# Out:
#        t_date t_close_last
# 8  2020-01-02      $28.684
# 9  2020-05-01     $46.7547
# 6  2020-09-01      $158.35
# 4  2021-01-04    $243.2566
# 7  2021-05-03      $228.30
# 2  2021-09-01    $244.6966
# 0  2022-01-03    $399.9266
# 1  2022-05-02      $300.98
# 3  2022-09-01      $277.16
# 11 2023-01-03      $108.10
# 5  2023-05-01      $161.83
# 10 2023-09-01      $245.01

# %% [markdown]
# # TECH

# %%
query = '''
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '2020-01-02'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '2020-05-01'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '2020-09-01'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '01/04/2021'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '05/03/2021'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '9/1/2021'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '1/3/2022'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '5/2/2022'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '9/1/2022'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '1/3/2023'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '5/1/2023'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '9/1/2023'
UNION
SELECT a_date, a_close_last
FROM apple_stock
WHERE a_date = '05/01/2020	';
;
'''

with engine.connect() as connection:
 result = connection.execute(text(query))
with engine.connect() as connection:
     sc2= pd.read_sql(text(query), con = connection)
sc2.head(50)
# Out:
#         a_date a_close_last
# 0   2022-05-02      $157.96
# 1   2023-05-01      $169.59
# 2   2023-01-03      $125.07
# 3   2020-01-02     $75.0875
# 4   2021-01-04      $129.41
# 5   2022-09-01      $157.96
# 6   2020-05-01     $72.2675
# 7   2021-09-01      $152.51
# 8   2021-05-03      $132.54
# 9   2023-09-01      $189.46
# 10  2022-01-03      $182.01
# 11  2020-09-01      $134.18

# %%
sc22 = sc1.sort_values(by='a_date')

# %%
sc22
# Out:
#         a_date a_close_last
# 3   2020-01-02     $75.0875
# 6   2020-05-01     $72.2675
# 11  2020-09-01      $134.18
# 4   2021-01-04      $129.41
# 8   2021-05-03      $132.54
# 7   2021-09-01      $152.51
# 10  2022-01-03      $182.01
# 0   2022-05-02      $157.96
# 5   2022-09-01      $157.96
# 2   2023-01-03      $125.07
# 1   2023-05-01      $169.59
# 9   2023-09-01      $189.46
